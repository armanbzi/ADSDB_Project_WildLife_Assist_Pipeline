# %%
"""
-Arman Bazarchi-
Persistent_Landing Zone
...



"""


from minio import Minio
import pandas as pd
import io
import os
from datetime import datetime
import re
import sys

# ==============================
# 1️⃣ Configuration
# ==============================
MINIO_ENDPOINT = "localhost:9000"
ACCESS_KEY = "admin"
SECRET_KEY = "password123"
ROOT_BUCKET = "landing-zone"                 # Main bucket
TEMP_PREFIX = "temporal-landing"             # Source (subbucket)
PERSIST_PREFIX = "persistent_landing"        # Destination (subbucket)
TEMP_METADATA_PATH = f"{TEMP_PREFIX}/metadata/metadata_final.csv"

# ==============================
# 2️⃣ Connect to MinIO
# ==============================
client = Minio(
    MINIO_ENDPOINT,
    access_key=ACCESS_KEY,
    secret_key=SECRET_KEY,
    secure=False
)

# ==============================
# 3️⃣ Validate buckets
# ==============================
if not client.bucket_exists(ROOT_BUCKET):
    sys.exit("❌ ERROR: Root bucket 'Landing' does not exist in MinIO.")

temporal_exists = any(
    obj.object_name.startswith(f"{TEMP_PREFIX}/")
    for obj in client.list_objects(ROOT_BUCKET, recursive=False)
)
if not temporal_exists:
    sys.exit("❌ ERROR: 'Temporal_Landing' does not exist inside 'Landing' bucket.")

# Create Persistent_Landing if missing
persistent_exists = any(
    obj.object_name.startswith(f"{PERSIST_PREFIX}/")
    for obj in client.list_objects(ROOT_BUCKET, recursive=False)
)
if not persistent_exists:
    client.put_object(
        ROOT_BUCKET,
        f"{PERSIST_PREFIX}/.init",
        data=io.BytesIO(b"init"),
        length=4,
        content_type="text/plain"
    )
    print(f"✅ Created 'Persistent_Landing' inside '{ROOT_BUCKET}'.")

# ==============================
# 4️⃣ Load metadata from Temporal_Landing
# ==============================
print("📥 Loading metadata from Temporal_Landing...")
LOCAL_METADATA = "temp_metadata.csv"
try:
    client.fget_object(ROOT_BUCKET, TEMP_METADATA_PATH, LOCAL_METADATA)
except Exception as e:
    sys.exit(f"❌ ERROR: Failed to find metadata at {TEMP_METADATA_PATH} → {e}")

metadata_df = pd.read_csv(LOCAL_METADATA)
print(f"✅ Loaded metadata with {len(metadata_df)} records.")

# ==============================
# 5️⃣ Scan existing Persistent images by UUID
# ==============================
print("🔍 Checking existing images in Persistent_Landing...")
existing_persistent_uuids = set()
for obj in client.list_objects(ROOT_BUCKET, prefix=f"{PERSIST_PREFIX}/images/", recursive=True):
    match = re.match(rf"{PERSIST_PREFIX}/images/.+?/([a-f0-9\-]+)\.jpg", obj.object_name)
    if match:
        existing_persistent_uuids.add(match.group(1))

print(f"📦 Found {len(existing_persistent_uuids)} existing images in Persistent_Landing.")
metadata_df["persistent_path"] = None

# ==============================
# 6️⃣ Move images from Temporal → Persistent
# ==============================
timestamp = datetime.now().strftime("%Y_%m_%d_%H:%M")
moved_records = []

for idx, row in metadata_df.iterrows():
    try:
        img_uuid = row.get("uuid")
        if not img_uuid:
            continue

        # Skip if image already exists in Persistent
        if img_uuid in existing_persistent_uuids:
            print(f"⏩ Skipping duplicate UUID: {img_uuid}")
            continue

        object_name = row.get("temporal_path") 
        src_path = object_name

        kingdom = str(row.get("kingdom", "Unknown")).replace(" ", "_")
        cls = str(row.get("class", "Unknown")).replace(" ", "_")
        family = str(row.get("family", "Unknown")).replace(" ", "_")
        specie = str(row.get("species", "Unknown")).replace(" ", "_")

        # Destination path using UUID
        dest_path = f"{PERSIST_PREFIX}/images/{kingdom}/{cls}/{family}/{specie}/{img_uuid}.jpg"
        metadata_df.loc[idx, "persistent_path"] = dest_path
        
        # Download image from Temporal
        data = client.get_object(ROOT_BUCKET, src_path)
        image_bytes = data.read()
        data.close()
        data.release_conn()

        # Upload image to Persistent
        client.put_object(
            ROOT_BUCKET,
            dest_path,
            data=io.BytesIO(image_bytes),
            length=len(image_bytes),
            content_type="image/jpeg"
        )

        
        moved_records.append(row)
        existing_persistent_uuids.add(img_uuid)

        print(f"✅ Moved {src_path} → {dest_path}")

    except Exception as e:
        print(f"⚠️ Error processing {object_name}: {e}")
        continue

# ==============================
# 7️⃣ Save or merge metadata files by (Kingdom, Class)
# ==============================
if not metadata_df.empty:
    print("🧠 Updating kingdom-class based metadata files...")

    for (kingdom_name, cls_name), group in metadata_df.groupby(["kingdom", "class"]):
        kingdom_safe = str(kingdom_name).replace(" ", "_")
        cls_safe = str(cls_name).replace(" ", "_")

        # Always create a new filename with current timestamp for updated metadata
        timestamp = datetime.now().strftime("%Y_%m_%d_%H:%M")
        metadata_filename = f"{kingdom_safe}_{cls_safe}_metadata_{timestamp}.csv"
        local_metadata_file = f"{kingdom_safe}_{cls_safe}_metadata_temp.csv"
        persistent_metadata_dir = f"{PERSIST_PREFIX}/metadata/"

        # Look for any existing metadata file for this kingdom+class
        existing_metadata_files = [
            obj.object_name for obj in client.list_objects(ROOT_BUCKET, prefix=persistent_metadata_dir, recursive=True)
            if re.match(rf"{persistent_metadata_dir}{kingdom_safe}_{cls_safe}_metadata_.*\.csv", obj.object_name)
        ]

        if existing_metadata_files:
            # Take the latest metadata file (any timestamp)
            existing_metadata_files.sort(reverse=True)
            existing_metadata_path = existing_metadata_files[0]
            existing_local_file = f"existing_{kingdom_safe}_{cls_safe}.csv"
            client.fget_object(ROOT_BUCKET, existing_metadata_path, existing_local_file)

            # Read existing metadata
            existing_df = pd.read_csv(existing_local_file)

            # Delete old file from Persistent
            client.remove_object(ROOT_BUCKET, existing_metadata_path)
            os.remove(existing_local_file)

            # Merge Temporal rows that are not already in Persistent
            new_rows = group[~group["uuid"].isin(existing_df["uuid"])]
            merged_df = pd.concat([existing_df, new_rows], ignore_index=True)
        else:
            # No existing metadata → just use all rows from Temporal
            group["persistent_path"]
            merged_df = group

        # Save merged metadata with updated timestamp
        merged_df.to_csv(local_metadata_file, index=False)
        persistent_metadata_path_new = f"{persistent_metadata_dir}{metadata_filename}"
        client.fput_object(
            ROOT_BUCKET,
            persistent_metadata_path_new,
            local_metadata_file,
            content_type="text/csv"
        )

        os.remove(local_metadata_file)
        print(f"📤 Updated/uploaded metadata for '{kingdom_safe}-{cls_safe}' → {persistent_metadata_path_new}")



    # Cleanup local temp
    os.remove(LOCAL_METADATA)
    print("🧹 Cleaned up local metadata files.")

else:
    print("⚠️ No new images moved; skipping metadata upload.")

print("✅ Persistent Landing Zone completed successfully.")
# Out:
# ✅ Created 'Persistent_Landing' inside 'landing-zone'.
# 📥 Loading metadata from Temporal_Landing...
# ✅ Loaded metadata with 736 records.
# 🔍 Checking existing images in Persistent_Landing...
# 📦 Found 0 existing images in Persistent_Landing.
# ✅ Moved temporal-landing/images/d0caebda-85d3-46fc-978e-58ca4c7d5cfd.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/d0caebda-85d3-46fc-978e-58ca4c7d5cfd.jpg
# ✅ Moved temporal-landing/images/cc3e8cd0-b993-4fdf-ae35-27880edf1597.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/cc3e8cd0-b993-4fdf-ae35-27880edf1597.jpg
# ✅ Moved temporal-landing/images/bafa2323-81f5-4783-bb58-6b5d26a2e1b7.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/bafa2323-81f5-4783-bb58-6b5d26a2e1b7.jpg
# ✅ Moved temporal-landing/images/9b074b8a-3fa2-4da5-9925-7f28ab1b9e36.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/dendrophila/9b074b8a-3fa2-4da5-9925-7f28ab1b9e36.jpg
# ✅ Moved temporal-landing/images/521e2087-5109-4c59-8719-539b5bb2989e.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/521e2087-5109-4c59-8719-539b5bb2989e.jpg
# ✅ Moved temporal-landing/images/98eef8f1-ac51-4f77-91dd-2d8e264a64bb.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/parvifrons/98eef8f1-ac51-4f77-91dd-2d8e264a64bb.jpg
# ✅ Moved temporal-landing/images/d29a4659-1428-4afe-b777-a85925700147.jpg → persistent_landing/images/Animalia/Squamata/Boidae/maurus/d29a4659-1428-4afe-b777-a85925700147.jpg
# ✅ Moved temporal-landing/images/107d8a0f-e3fa-4490-9c6f-2fa04ca23943.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/107d8a0f-e3fa-4490-9c6f-2fa04ca23943.jpg
# ✅ Moved temporal-landing/images/d93786f4-148d-4172-85df-d94d6de9160e.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/d93786f4-148d-4172-85df-d94d6de9160e.jpg
# ✅ Moved temporal-landing/images/63fb9c28-b8a4-4f67-8599-b5e00be6f3d5.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/63fb9c28-b8a4-4f67-8599-b5e00be6f3d5.jpg
# ✅ Moved temporal-landing/images/592e5467-c53b-4274-a7f2-7842342d98fe.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/592e5467-c53b-4274-a7f2-7842342d98fe.jpg
# ✅ Moved temporal-landing/images/1aeab32b-8d2e-4d25-a634-e7d879c74c13.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/1aeab32b-8d2e-4d25-a634-e7d879c74c13.jpg
# ✅ Moved temporal-landing/images/77a23dbb-ddf2-4681-880e-755c94780280.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/77a23dbb-ddf2-4681-880e-755c94780280.jpg
# ✅ Moved temporal-landing/images/2742a3b6-eb94-49b3-bf06-292f1cd0f150.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/2742a3b6-eb94-49b3-bf06-292f1cd0f150.jpg
# ✅ Moved temporal-landing/images/e33a4fb3-950d-4f91-81c4-d495eac0d2e6.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/e33a4fb3-950d-4f91-81c4-d495eac0d2e6.jpg
# ✅ Moved temporal-landing/images/9498b732-0821-42ad-9f86-9fd0b5094ac1.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/superbus/9498b732-0821-42ad-9f86-9fd0b5094ac1.jpg
# ✅ Moved temporal-landing/images/56d9ba4f-f6b4-4d3f-a82a-738f96b74e74.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/totonacus/56d9ba4f-f6b4-4d3f-a82a-738f96b74e74.jpg
# ✅ Moved temporal-landing/images/d61613db-99ca-478c-828d-0f556217fdd0.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/d61613db-99ca-478c-828d-0f556217fdd0.jpg
# ✅ Moved temporal-landing/images/41500261-4e9c-4c24-aaba-5a7caaa6e685.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/41500261-4e9c-4c24-aaba-5a7caaa6e685.jpg
# ✅ Moved temporal-landing/images/9d62291e-52ca-46a9-85bb-090cb5099ba8.jpg → persistent_landing/images/Animalia/Squamata/Boidae/bottae/9d62291e-52ca-46a9-85bb-090cb5099ba8.jpg
# ✅ Moved temporal-landing/images/d1bf488f-8d2a-4d31-ba85-d210a0dea75c.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/d1bf488f-8d2a-4d31-ba85-d210a0dea75c.jpg
# ✅ Moved temporal-landing/images/13493fae-0a6f-47c4-8f90-cf5accbd8e03.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/bivittatus/13493fae-0a6f-47c4-8f90-cf5accbd8e03.jpg
# ✅ Moved temporal-landing/images/935c45d4-390a-4719-8434-7987905ff5ca.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/935c45d4-390a-4719-8434-7987905ff5ca.jpg
# ✅ Moved temporal-landing/images/87a42362-eb48-4666-bae9-513003c99197.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/87a42362-eb48-4666-bae9-513003c99197.jpg
# ✅ Moved temporal-landing/images/1f836943-141a-4c85-b04b-3e2b09b4e5e3.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/1f836943-141a-4c85-b04b-3e2b09b4e5e3.jpg
# ✅ Moved temporal-landing/images/dc8d2462-d8dc-4d6a-afdb-ede70dc6aa31.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/dc8d2462-d8dc-4d6a-afdb-ede70dc6aa31.jpg
# ✅ Moved temporal-landing/images/315fcbc6-cf59-4bed-8831-ce5d16232ea3.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/carinatus/315fcbc6-cf59-4bed-8831-ce5d16232ea3.jpg
# ✅ Moved temporal-landing/images/044068d2-d3b4-43b9-a00d-89625dea8f1b.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/044068d2-d3b4-43b9-a00d-89625dea8f1b.jpg
# ✅ Moved temporal-landing/images/991f0b79-5322-4613-882b-ae51f5da6971.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/991f0b79-5322-4613-882b-ae51f5da6971.jpg
# ✅ Moved temporal-landing/images/38387823-faec-41fc-be89-6f76354b4e3d.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/38387823-faec-41fc-be89-6f76354b4e3d.jpg
# ✅ Moved temporal-landing/images/a4b4f20a-8fc5-4314-b2b6-b849e6ab7244.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/a4b4f20a-8fc5-4314-b2b6-b849e6ab7244.jpg
# ✅ Moved temporal-landing/images/dacac29c-e03c-40c1-82af-b9826b30414f.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/dacac29c-e03c-40c1-82af-b9826b30414f.jpg
# ✅ Moved temporal-landing/images/c5cd7a78-e3b2-43f1-9805-3a6af728dba8.jpg → persistent_landing/images/Animalia/Squamata/Cylindrophiidae/melanotus/c5cd7a78-e3b2-43f1-9805-3a6af728dba8.jpg
# ✅ Moved temporal-landing/images/7a64e16f-899e-43ff-a137-140712204f55.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/naja/7a64e16f-899e-43ff-a137-140712204f55.jpg
# ✅ Moved temporal-landing/images/c9ce26a5-4969-4735-8465-866f89890d26.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/c9ce26a5-4969-4735-8465-866f89890d26.jpg
# ✅ Moved temporal-landing/images/2679a66b-7c00-4c41-959b-b619b1240619.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/2679a66b-7c00-4c41-959b-b619b1240619.jpg
# ✅ Moved temporal-landing/images/c40bf432-058b-4227-b6a6-b1ff6a861e98.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/c40bf432-058b-4227-b6a6-b1ff6a861e98.jpg
# ✅ Moved temporal-landing/images/63b63fb4-2625-434e-82d3-9418c630f90a.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/63b63fb4-2625-434e-82d3-9418c630f90a.jpg
# ✅ Moved temporal-landing/images/7daa6a47-9a42-4789-beef-ffdb024035bf.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/7daa6a47-9a42-4789-beef-ffdb024035bf.jpg
# ✅ Moved temporal-landing/images/69de984f-d82b-45aa-a562-0c6754216551.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/superbus/69de984f-d82b-45aa-a562-0c6754216551.jpg
# ✅ Moved temporal-landing/images/4034278f-3279-48c5-aa97-f0d2f8001413.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/4034278f-3279-48c5-aa97-f0d2f8001413.jpg
# ✅ Moved temporal-landing/images/147ba12a-bf01-4617-9f54-03590015ba85.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/bivittatus/147ba12a-bf01-4617-9f54-03590015ba85.jpg
# ✅ Moved temporal-landing/images/0c7641a9-dcc6-429d-9260-5756edf81393.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/0c7641a9-dcc6-429d-9260-5756edf81393.jpg
# ✅ Moved temporal-landing/images/b29a3801-2ab1-4ee1-b47e-b750ab147279.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/b29a3801-2ab1-4ee1-b47e-b750ab147279.jpg
# ✅ Moved temporal-landing/images/982e84db-abbc-4119-875c-e21e60e34a08.jpg → persistent_landing/images/Animalia/Squamata/Boidae/unknown/982e84db-abbc-4119-875c-e21e60e34a08.jpg
# ✅ Moved temporal-landing/images/d893eea8-9c17-4506-a0a5-d73389be391c.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/nanum/d893eea8-9c17-4506-a0a5-d73389be391c.jpg
# ✅ Moved temporal-landing/images/148f0fea-0f70-44c4-9cce-278fcf19fb6b.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/148f0fea-0f70-44c4-9cce-278fcf19fb6b.jpg
# ✅ Moved temporal-landing/images/169e7fda-703e-417c-a2d4-902bd331e3cf.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/inornatus/169e7fda-703e-417c-a2d4-902bd331e3cf.jpg
# ✅ Moved temporal-landing/images/298d9e4b-1d75-4136-b06c-88abfbdc17e6.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/multicinctus/298d9e4b-1d75-4136-b06c-88abfbdc17e6.jpg
# ✅ Moved temporal-landing/images/4aedc286-e76f-4fa4-aba3-e7605b1ee0a5.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/4aedc286-e76f-4fa4-aba3-e7605b1ee0a5.jpg
# ✅ Moved temporal-landing/images/d9022ee9-6f94-44cd-8882-65b15d495cc0.jpg → persistent_landing/images/Animalia/Squamata/Leptotyphlopidae/dulcis/d9022ee9-6f94-44cd-8882-65b15d495cc0.jpg
# ✅ Moved temporal-landing/images/7c4a21fd-0bd1-4ebc-8b60-8f8d08742c4d.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/7c4a21fd-0bd1-4ebc-8b60-8f8d08742c4d.jpg
# ✅ Moved temporal-landing/images/25c1f074-7330-4e60-a71e-a527ed4fb17e.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/25c1f074-7330-4e60-a71e-a527ed4fb17e.jpg
# ✅ Moved temporal-landing/images/975adf80-2722-414a-90cb-d22c0f9a726b.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/975adf80-2722-414a-90cb-d22c0f9a726b.jpg
# ✅ Moved temporal-landing/images/d5b7b790-e1e7-4f2b-aec1-68c20b7e3e4c.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/d5b7b790-e1e7-4f2b-aec1-68c20b7e3e4c.jpg
# ✅ Moved temporal-landing/images/7ddc7228-2b25-44fe-b1a3-7a27a376ee2d.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/7ddc7228-2b25-44fe-b1a3-7a27a376ee2d.jpg
# ✅ Moved temporal-landing/images/80bb6e47-7ee1-47fe-8f09-73d5c1dd552a.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/80bb6e47-7ee1-47fe-8f09-73d5c1dd552a.jpg
# ✅ Moved temporal-landing/images/79fe5e7e-2ae0-4643-b6dc-8a7fc15820ad.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/79fe5e7e-2ae0-4643-b6dc-8a7fc15820ad.jpg
# ✅ Moved temporal-landing/images/4fecde7b-87d0-48a0-ac91-5913e3d41229.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/4fecde7b-87d0-48a0-ac91-5913e3d41229.jpg
# ✅ Moved temporal-landing/images/3d608f8c-bf95-4744-8daf-e9ecaf51e8d5.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/3d608f8c-bf95-4744-8daf-e9ecaf51e8d5.jpg
# ✅ Moved temporal-landing/images/9b7755be-c6b2-4c7f-b25a-1c002ba43a96.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/9b7755be-c6b2-4c7f-b25a-1c002ba43a96.jpg
# ✅ Moved temporal-landing/images/1fd43092-b010-4e7c-9698-955f5c572ec6.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/1fd43092-b010-4e7c-9698-955f5c572ec6.jpg
# ✅ Moved temporal-landing/images/a58c14e1-1bf7-4671-818a-28d253326f7d.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/a58c14e1-1bf7-4671-818a-28d253326f7d.jpg
# ✅ Moved temporal-landing/images/e5b34353-f5ab-41b3-a6e6-96474002913a.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/e5b34353-f5ab-41b3-a6e6-96474002913a.jpg
# ✅ Moved temporal-landing/images/b269df36-8a06-4a15-a3d5-1c24ea4c9f97.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/b269df36-8a06-4a15-a3d5-1c24ea4c9f97.jpg
# ✅ Moved temporal-landing/images/b30e582e-2ac3-46b9-803e-8fbbaabe4be1.jpg → persistent_landing/images/Animalia/Squamata/Boidae/carinata/b30e582e-2ac3-46b9-803e-8fbbaabe4be1.jpg
# ✅ Moved temporal-landing/images/262b90c7-0a7c-4f67-97a3-176473a1dec5.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/262b90c7-0a7c-4f67-97a3-176473a1dec5.jpg
# ✅ Moved temporal-landing/images/df8c1c04-27d3-40ed-b85a-b129a3a34311.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/df8c1c04-27d3-40ed-b85a-b129a3a34311.jpg
# ✅ Moved temporal-landing/images/9f46b359-4a9b-429a-8ce1-e24cff8f29c1.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/9f46b359-4a9b-429a-8ce1-e24cff8f29c1.jpg
# ✅ Moved temporal-landing/images/955acdfe-c82f-4980-b480-b08bada7abb9.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/955acdfe-c82f-4980-b480-b08bada7abb9.jpg
# ✅ Moved temporal-landing/images/3e8cc9d5-12de-448b-90fb-ec74d881d5aa.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/3e8cc9d5-12de-448b-90fb-ec74d881d5aa.jpg
# ✅ Moved temporal-landing/images/4704788c-20d3-4293-855b-e6b6ea840e99.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/4704788c-20d3-4293-855b-e6b6ea840e99.jpg
# ✅ Moved temporal-landing/images/30f07493-a3eb-4873-aa10-8629c96dce21.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/30f07493-a3eb-4873-aa10-8629c96dce21.jpg
# ✅ Moved temporal-landing/images/7ce56a32-fbb9-40b6-a387-f06cc7146d3a.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/7ce56a32-fbb9-40b6-a387-f06cc7146d3a.jpg
# ✅ Moved temporal-landing/images/74c8d04e-4354-428c-9a53-b612d4110e7e.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/74c8d04e-4354-428c-9a53-b612d4110e7e.jpg
# ✅ Moved temporal-landing/images/5df6c9b0-d5d4-46f6-b109-e13bfd4641e3.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/5df6c9b0-d5d4-46f6-b109-e13bfd4641e3.jpg
# ✅ Moved temporal-landing/images/e862f02e-5da4-47bf-a033-b49f2b2d1868.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/e862f02e-5da4-47bf-a033-b49f2b2d1868.jpg
# ✅ Moved temporal-landing/images/74db93d3-d4d9-4726-be46-bc573479b8fc.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/74db93d3-d4d9-4726-be46-bc573479b8fc.jpg
# ✅ Moved temporal-landing/images/a8ec0ece-f9ca-4dbb-b823-b14e23eda458.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/a8ec0ece-f9ca-4dbb-b823-b14e23eda458.jpg
# ✅ Moved temporal-landing/images/eb4b220a-5bef-4a44-90bd-541fc25efd3f.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/eb4b220a-5bef-4a44-90bd-541fc25efd3f.jpg
# ✅ Moved temporal-landing/images/7b4b0721-ed08-479a-99fc-17a80d094dbe.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/bivittatus/7b4b0721-ed08-479a-99fc-17a80d094dbe.jpg
# ✅ Moved temporal-landing/images/34758d30-7a22-4657-8c82-0143cd1356b6.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/34758d30-7a22-4657-8c82-0143cd1356b6.jpg
# ✅ Moved temporal-landing/images/982dbe73-cfff-4ec0-9853-827620ab7efe.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/982dbe73-cfff-4ec0-9853-827620ab7efe.jpg
# ✅ Moved temporal-landing/images/0a76f922-3fe8-4bc4-9b5c-725c147ada1c.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/0a76f922-3fe8-4bc4-9b5c-725c147ada1c.jpg
# ✅ Moved temporal-landing/images/7d94d7d4-e169-40df-a701-291a6e06ce68.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/syriacus/7d94d7d4-e169-40df-a701-291a6e06ce68.jpg
# ✅ Moved temporal-landing/images/be21c8ab-e012-42df-b215-0d7bf443d7b6.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/be21c8ab-e012-42df-b215-0d7bf443d7b6.jpg
# ✅ Moved temporal-landing/images/41ff692e-d97b-48f4-ac91-399d4be1c2a8.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/41ff692e-d97b-48f4-ac91-399d4be1c2a8.jpg
# ✅ Moved temporal-landing/images/de083a69-b23c-4e88-914a-d493902cce1a.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/de083a69-b23c-4e88-914a-d493902cce1a.jpg
# ✅ Moved temporal-landing/images/c9fb0bd9-6dbd-49e1-ad35-a6a1212467ab.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/c9fb0bd9-6dbd-49e1-ad35-a6a1212467ab.jpg
# ✅ Moved temporal-landing/images/939b4c4e-82d0-41f0-9c50-d9389c737086.jpg → persistent_landing/images/Animalia/Squamata/Boidae/maurus/939b4c4e-82d0-41f0-9c50-d9389c737086.jpg
# ✅ Moved temporal-landing/images/df1986bf-806c-442c-ac5e-053e4c50c6ec.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/df1986bf-806c-442c-ac5e-053e4c50c6ec.jpg
# ✅ Moved temporal-landing/images/3c0cc682-3837-49fe-975f-8a928620603d.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/3c0cc682-3837-49fe-975f-8a928620603d.jpg
# ✅ Moved temporal-landing/images/ec55e00a-736d-43e8-a832-32bcede851b3.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/ec55e00a-736d-43e8-a832-32bcede851b3.jpg
# ✅ Moved temporal-landing/images/2f1ede7b-daec-462c-8623-8f45138c6e99.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/2f1ede7b-daec-462c-8623-8f45138c6e99.jpg
# ✅ Moved temporal-landing/images/00b968c9-ec9e-4f02-90cd-b3efdb08e913.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/bivittatus/00b968c9-ec9e-4f02-90cd-b3efdb08e913.jpg
# ✅ Moved temporal-landing/images/3ad83198-3a67-417a-b707-f204f5c5ac63.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/capensis/3ad83198-3a67-417a-b707-f204f5c5ac63.jpg
# ✅ Moved temporal-landing/images/c4b4f117-9b1c-4651-8510-46922c2599d5.jpg → persistent_landing/images/Animalia/Squamata/Uropeltidae/maculata/c4b4f117-9b1c-4651-8510-46922c2599d5.jpg
# ✅ Moved temporal-landing/images/1627309e-297f-4eb3-a3d0-912872d6773d.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/1627309e-297f-4eb3-a3d0-912872d6773d.jpg
# ✅ Moved temporal-landing/images/096120c9-ad30-4831-9d1a-6565b2787c0e.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/096120c9-ad30-4831-9d1a-6565b2787c0e.jpg
# ✅ Moved temporal-landing/images/4bae6549-2b16-42d7-843c-75b9246a7337.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/4bae6549-2b16-42d7-843c-75b9246a7337.jpg
# ✅ Moved temporal-landing/images/687f76bf-d01f-4780-a85c-0daf21842567.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/687f76bf-d01f-4780-a85c-0daf21842567.jpg
# ✅ Moved temporal-landing/images/28a1def3-92a5-4bbd-8c4c-f5b0b92ef689.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/28a1def3-92a5-4bbd-8c4c-f5b0b92ef689.jpg
# ✅ Moved temporal-landing/images/256cf78d-551e-49d1-9bf2-15202a0e0cb3.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/256cf78d-551e-49d1-9bf2-15202a0e0cb3.jpg
# ✅ Moved temporal-landing/images/ee30369e-5558-41ec-8599-54a1afc684e1.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/ee30369e-5558-41ec-8599-54a1afc684e1.jpg
# ✅ Moved temporal-landing/images/d7f77ce6-6bf2-40cd-a01e-40a2270490b1.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/capensis/d7f77ce6-6bf2-40cd-a01e-40a2270490b1.jpg
# ✅ Moved temporal-landing/images/15558978-1d8a-4cb8-9659-a28fdba3baf9.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/15558978-1d8a-4cb8-9659-a28fdba3baf9.jpg
# ✅ Moved temporal-landing/images/a252696a-7ad9-46f1-b83b-558d4fabd7d5.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/breitensteini/a252696a-7ad9-46f1-b83b-558d4fabd7d5.jpg
# ✅ Moved temporal-landing/images/1aa3445b-8f0d-4ac7-af6b-754b9be6ec13.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/1aa3445b-8f0d-4ac7-af6b-754b9be6ec13.jpg
# ✅ Moved temporal-landing/images/14837bb9-549b-4db9-bbd5-a8d4de405e52.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/14837bb9-549b-4db9-bbd5-a8d4de405e52.jpg
# ✅ Moved temporal-landing/images/e3559e7c-feea-417a-b5fa-97391972017a.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/e3559e7c-feea-417a-b5fa-97391972017a.jpg
# ✅ Moved temporal-landing/images/7a904671-6e48-4852-b44a-1d1230706b3d.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/7a904671-6e48-4852-b44a-1d1230706b3d.jpg
# ✅ Moved temporal-landing/images/50b60ab2-6b97-4be3-92a1-6ab984565bc0.jpg → persistent_landing/images/Animalia/Squamata/Boidae/bottae/50b60ab2-6b97-4be3-92a1-6ab984565bc0.jpg
# ✅ Moved temporal-landing/images/24196d03-0d8e-4c5f-9906-0f98dae6cd20.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/24196d03-0d8e-4c5f-9906-0f98dae6cd20.jpg
# ✅ Moved temporal-landing/images/aa1dcaf6-aa0d-4dbd-9272-c6f2e515fbcf.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/aa1dcaf6-aa0d-4dbd-9272-c6f2e515fbcf.jpg
# ✅ Moved temporal-landing/images/bace78b8-d6e3-45e6-a22d-19125df740ed.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/bace78b8-d6e3-45e6-a22d-19125df740ed.jpg
# ✅ Moved temporal-landing/images/a36e8587-9581-4037-85fe-3f9c5937a079.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/a36e8587-9581-4037-85fe-3f9c5937a079.jpg
# ✅ Moved temporal-landing/images/6f5d0a47-6cde-4716-81f4-c1cb378ce5e9.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/6f5d0a47-6cde-4716-81f4-c1cb378ce5e9.jpg
# ✅ Moved temporal-landing/images/c0cf110d-4ff9-4b75-a4aa-1cdfa37502ab.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/c0cf110d-4ff9-4b75-a4aa-1cdfa37502ab.jpg
# ✅ Moved temporal-landing/images/bbb21907-4d31-4dff-9e01-4c5d2bcae1be.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/bbb21907-4d31-4dff-9e01-4c5d2bcae1be.jpg
# ✅ Moved temporal-landing/images/7dac65ce-a66a-4306-b780-ea4f3a150ae5.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/constrictor/7dac65ce-a66a-4306-b780-ea4f3a150ae5.jpg
# ✅ Moved temporal-landing/images/9d23e8b2-bae1-4b76-b662-4841ace779a3.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/sipedon/9d23e8b2-bae1-4b76-b662-4841ace779a3.jpg
# ✅ Moved temporal-landing/images/c7b4f004-7ef6-4507-a633-d74f361feb07.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/c7b4f004-7ef6-4507-a633-d74f361feb07.jpg
# ✅ Moved temporal-landing/images/959ec3e1-5f36-40b6-a8cd-65cd7fb18e10.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/959ec3e1-5f36-40b6-a8cd-65cd7fb18e10.jpg
# ✅ Moved temporal-landing/images/d8cb1dc1-b141-46c2-acdb-4dacf3a28137.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/d8cb1dc1-b141-46c2-acdb-4dacf3a28137.jpg
# ✅ Moved temporal-landing/images/5d229df6-7b83-4446-ab06-c4d1ccc1bf76.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/bivittatus/5d229df6-7b83-4446-ab06-c4d1ccc1bf76.jpg
# ✅ Moved temporal-landing/images/814c87e4-5db4-4a52-a645-b468051de486.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/814c87e4-5db4-4a52-a645-b468051de486.jpg
# ✅ Moved temporal-landing/images/56e61947-ab9b-4d23-adda-f21bd07c50bc.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/56e61947-ab9b-4d23-adda-f21bd07c50bc.jpg
# ✅ Moved temporal-landing/images/6fd78f5c-5036-4545-b692-7b0c4d370890.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/6fd78f5c-5036-4545-b692-7b0c4d370890.jpg
# ✅ Moved temporal-landing/images/520fcd2f-a7fc-4125-a074-25eb13b91ed9.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/520fcd2f-a7fc-4125-a074-25eb13b91ed9.jpg
# ✅ Moved temporal-landing/images/24dd6516-1cd2-4fdc-8f88-e0ee04909b26.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/24dd6516-1cd2-4fdc-8f88-e0ee04909b26.jpg
# ✅ Moved temporal-landing/images/da966e52-a4dc-4680-905b-b52056612a94.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/da966e52-a4dc-4680-905b-b52056612a94.jpg
# ✅ Moved temporal-landing/images/4a335855-c8cf-4529-80b8-d50527d69575.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/4a335855-c8cf-4529-80b8-d50527d69575.jpg
# ✅ Moved temporal-landing/images/65f52928-7692-4a33-8b14-67209eec4145.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/65f52928-7692-4a33-8b14-67209eec4145.jpg
# ✅ Moved temporal-landing/images/c5e7725e-2e25-45e8-b0fb-4f6947f1a0b4.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/c5e7725e-2e25-45e8-b0fb-4f6947f1a0b4.jpg
# ✅ Moved temporal-landing/images/47b20434-e2f2-41e7-9489-96a59ae50847.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/multicinctus/47b20434-e2f2-41e7-9489-96a59ae50847.jpg
# ✅ Moved temporal-landing/images/9240074d-7ef0-4f68-949c-04227c20e994.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/9240074d-7ef0-4f68-949c-04227c20e994.jpg
# ✅ Moved temporal-landing/images/376a6b9e-4858-4133-99a8-6f61000a67c8.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/376a6b9e-4858-4133-99a8-6f61000a67c8.jpg
# ✅ Moved temporal-landing/images/1467e6fa-7690-4d90-8866-3ebfc5919b73.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/1467e6fa-7690-4d90-8866-3ebfc5919b73.jpg
# ✅ Moved temporal-landing/images/ba0a7b36-3b76-446c-9b99-c4a7c54304b1.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/ba0a7b36-3b76-446c-9b99-c4a7c54304b1.jpg
# ✅ Moved temporal-landing/images/e4cf278a-b4f6-43dd-99a3-7da8215f9f65.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/e4cf278a-b4f6-43dd-99a3-7da8215f9f65.jpg
# ✅ Moved temporal-landing/images/313b4c95-3443-4c39-b136-b26f3afef102.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/313b4c95-3443-4c39-b136-b26f3afef102.jpg
# ✅ Moved temporal-landing/images/194ad219-d470-4987-a623-90cd304f400d.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/194ad219-d470-4987-a623-90cd304f400d.jpg
# ✅ Moved temporal-landing/images/a24b521d-b6d6-42b6-b530-bc8652128780.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/oreganus/a24b521d-b6d6-42b6-b530-bc8652128780.jpg
# ✅ Moved temporal-landing/images/37e35813-9dc1-4bbe-90aa-f1e84777303a.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/37e35813-9dc1-4bbe-90aa-f1e84777303a.jpg
# ✅ Moved temporal-landing/images/74ef2643-787d-4f95-994b-7454b7fd77a6.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/74ef2643-787d-4f95-994b-7454b7fd77a6.jpg
# ✅ Moved temporal-landing/images/bdd22084-bbdb-45be-bceb-b4d717e3f1c8.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/bdd22084-bbdb-45be-bceb-b4d717e3f1c8.jpg
# ✅ Moved temporal-landing/images/9fa2219b-434b-4a3d-bf67-d38b276ba585.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/9fa2219b-434b-4a3d-bf67-d38b276ba585.jpg
# ✅ Moved temporal-landing/images/9928a9c7-7b83-4e9d-b39a-5301bf2cb7c4.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/9928a9c7-7b83-4e9d-b39a-5301bf2cb7c4.jpg
# ✅ Moved temporal-landing/images/ed7abf40-efed-4a87-8680-becd135f3ab1.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/ed7abf40-efed-4a87-8680-becd135f3ab1.jpg
# ✅ Moved temporal-landing/images/8b5e77ce-1fab-4d5f-9ae5-247165a20e46.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/8b5e77ce-1fab-4d5f-9ae5-247165a20e46.jpg
# ✅ Moved temporal-landing/images/0458f8e5-fda4-424d-bc34-929070b13f1b.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/0458f8e5-fda4-424d-bc34-929070b13f1b.jpg
# ✅ Moved temporal-landing/images/2b55aa81-f246-4eb6-a9e6-6da92d4814b1.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/aurora/2b55aa81-f246-4eb6-a9e6-6da92d4814b1.jpg
# ✅ Moved temporal-landing/images/30b002e2-dd2a-41e8-b175-ab2661999ba2.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/30b002e2-dd2a-41e8-b175-ab2661999ba2.jpg
# ✅ Moved temporal-landing/images/bfdc3469-1a9d-4f97-bfef-b2f15c766911.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/bfdc3469-1a9d-4f97-bfef-b2f15c766911.jpg
# ✅ Moved temporal-landing/images/5898c8c7-a9a1-4484-b8a9-f3be23ce7cd4.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/natrix/5898c8c7-a9a1-4484-b8a9-f3be23ce7cd4.jpg
# ✅ Moved temporal-landing/images/7de37a61-3869-4480-a561-9e3be4d049e1.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/7de37a61-3869-4480-a561-9e3be4d049e1.jpg
# ✅ Moved temporal-landing/images/3b8f58bb-2f00-41a6-af89-be2c837a8073.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/3b8f58bb-2f00-41a6-af89-be2c837a8073.jpg
# ✅ Moved temporal-landing/images/aa05712a-8616-4206-afbf-d4e0daf3cad9.jpg → persistent_landing/images/Animalia/Squamata/Leptotyphlopidae/merkeri/aa05712a-8616-4206-afbf-d4e0daf3cad9.jpg
# ✅ Moved temporal-landing/images/eb815206-0ea7-4fec-a7b0-f89faebcc460.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/superbus/eb815206-0ea7-4fec-a7b0-f89faebcc460.jpg
# ✅ Moved temporal-landing/images/05470e46-de8d-47ea-be5f-9ebf4a379b15.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lacteus/05470e46-de8d-47ea-be5f-9ebf4a379b15.jpg
# ✅ Moved temporal-landing/images/50528416-f2f3-4a71-9ea0-9198f9ef8644.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/50528416-f2f3-4a71-9ea0-9198f9ef8644.jpg
# ✅ Moved temporal-landing/images/1897aa73-1239-4f61-a3f7-7e073f95590c.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capense/1897aa73-1239-4f61-a3f7-7e073f95590c.jpg
# ✅ Moved temporal-landing/images/d8454eb7-d19b-429a-aa0f-9b8e5f53f219.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/d8454eb7-d19b-429a-aa0f-9b8e5f53f219.jpg
# ✅ Moved temporal-landing/images/24f36306-1464-4ced-aeb7-8e0f1eb1c03d.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/24f36306-1464-4ced-aeb7-8e0f1eb1c03d.jpg
# ✅ Moved temporal-landing/images/ed67abf5-2d60-480c-a5d9-fdddb02c2959.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/ed67abf5-2d60-480c-a5d9-fdddb02c2959.jpg
# ✅ Moved temporal-landing/images/12c2cb58-5c55-4d47-a113-20a85ef3f7c3.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capensis/12c2cb58-5c55-4d47-a113-20a85ef3f7c3.jpg
# ✅ Moved temporal-landing/images/56248a0c-65b0-4ada-ba22-c0fe556722b6.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/56248a0c-65b0-4ada-ba22-c0fe556722b6.jpg
# ✅ Moved temporal-landing/images/aca1e89f-83be-4111-807b-ad3de8487bde.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/natalensis/aca1e89f-83be-4111-807b-ad3de8487bde.jpg
# ✅ Moved temporal-landing/images/a6e3e0cc-314b-4781-bd90-ef09c9220028.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/a6e3e0cc-314b-4781-bd90-ef09c9220028.jpg
# ✅ Moved temporal-landing/images/b3a9fab2-feb6-4dc0-bc74-8c9b74208553.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capensis/b3a9fab2-feb6-4dc0-bc74-8c9b74208553.jpg
# ✅ Moved temporal-landing/images/7f2b3ad0-09f0-4fec-bf8e-fd4b65418f73.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/7f2b3ad0-09f0-4fec-bf8e-fd4b65418f73.jpg
# ✅ Moved temporal-landing/images/7ace56d8-b0d4-4011-90be-857f13a63b96.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/imbricata/7ace56d8-b0d4-4011-90be-857f13a63b96.jpg
# ✅ Moved temporal-landing/images/6774424d-9334-4240-9013-774af7ebafa5.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lunulatus/6774424d-9334-4240-9013-774af7ebafa5.jpg
# ✅ Moved temporal-landing/images/80535b3a-04c5-43c9-a1bf-94fc4ef5f80e.jpg → persistent_landing/images/Animalia/Squamata/Cylindrophiidae/ruffus/80535b3a-04c5-43c9-a1bf-94fc4ef5f80e.jpg
# ✅ Moved temporal-landing/images/326d7d73-4e8e-47ec-afed-1aed4b09d704.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/naja/326d7d73-4e8e-47ec-afed-1aed4b09d704.jpg
# ✅ Moved temporal-landing/images/6d3c7e22-7f21-4929-b4eb-59b346464a4d.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/6d3c7e22-7f21-4929-b4eb-59b346464a4d.jpg
# ✅ Moved temporal-landing/images/3ff70261-fa09-4718-9557-fba0a3de81ed.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/3ff70261-fa09-4718-9557-fba0a3de81ed.jpg
# ✅ Moved temporal-landing/images/81f2fcbd-6245-47f4-ab85-d0e675a4d8ea.jpg → persistent_landing/images/Animalia/Squamata/Boidae/bottae/81f2fcbd-6245-47f4-ab85-d0e675a4d8ea.jpg
# ✅ Moved temporal-landing/images/8dead312-d123-4928-b229-cc4d51a3908d.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/naja/8dead312-d123-4928-b229-cc4d51a3908d.jpg
# ✅ Moved temporal-landing/images/ce08c03b-0f81-44b7-95f9-63fabba0d948.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/ce08c03b-0f81-44b7-95f9-63fabba0d948.jpg
# ✅ Moved temporal-landing/images/55fe6dfc-f85d-4fd1-81e6-5438035fa3e3.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/55fe6dfc-f85d-4fd1-81e6-5438035fa3e3.jpg
# ✅ Moved temporal-landing/images/428accae-aa33-4247-9892-d14f1fe6185f.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/428accae-aa33-4247-9892-d14f1fe6185f.jpg
# ✅ Moved temporal-landing/images/c9c55191-0171-41e9-b9e0-e9f6861b9da6.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capensis/c9c55191-0171-41e9-b9e0-e9f6861b9da6.jpg
# ✅ Moved temporal-landing/images/2ea907b3-4a45-43df-9c11-6b789d7a2214.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/2ea907b3-4a45-43df-9c11-6b789d7a2214.jpg
# ✅ Moved temporal-landing/images/b35b9b0e-db4e-42e9-af5d-54b6916a9280.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/b35b9b0e-db4e-42e9-af5d-54b6916a9280.jpg
# ✅ Moved temporal-landing/images/b775163e-d5b0-4c1e-9e42-5940365760dd.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/b775163e-d5b0-4c1e-9e42-5940365760dd.jpg
# ✅ Moved temporal-landing/images/1302b891-2ea0-4cc3-84d5-75ed9774d139.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/1302b891-2ea0-4cc3-84d5-75ed9774d139.jpg
# ✅ Moved temporal-landing/images/7e1ed1fa-712f-41ad-9de3-34c0b2655550.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/7e1ed1fa-712f-41ad-9de3-34c0b2655550.jpg
# ✅ Moved temporal-landing/images/6257b377-6931-4649-8b5b-c550c2a52199.jpg → persistent_landing/images/Animalia/Squamata/Leptotyphlopidae/occidentalis/6257b377-6931-4649-8b5b-c550c2a52199.jpg
# ✅ Moved temporal-landing/images/87f0bf72-c97a-4cdc-bab9-cb2074799379.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/87f0bf72-c97a-4cdc-bab9-cb2074799379.jpg
# ✅ Moved temporal-landing/images/73586c4f-97d9-4148-83a9-f105146a354c.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/vermicularis/73586c4f-97d9-4148-83a9-f105146a354c.jpg
# ✅ Moved temporal-landing/images/bfa58967-287b-467d-9571-8ada89b0ae30.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/lalandei/bfa58967-287b-467d-9571-8ada89b0ae30.jpg
# ✅ Moved temporal-landing/images/67f5950e-9a0c-40a8-9ba7-d90c4fc05b78.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/67f5950e-9a0c-40a8-9ba7-d90c4fc05b78.jpg
# ✅ Moved temporal-landing/images/2fbe5e86-f416-42d3-b856-ca100c8d0ac6.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/2fbe5e86-f416-42d3-b856-ca100c8d0ac6.jpg
# ✅ Moved temporal-landing/images/5d59abee-846d-4e26-a215-71612a0fac94.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/multicinctus/5d59abee-846d-4e26-a215-71612a0fac94.jpg
# ✅ Moved temporal-landing/images/7dfcf978-e7f1-42f2-92d8-5640fd72de69.jpg → persistent_landing/images/Animalia/Squamata/Leptotyphlopidae/scutifrons/7dfcf978-e7f1-42f2-92d8-5640fd72de69.jpg
# ✅ Moved temporal-landing/images/3a88b3cf-0d10-4edc-b6b1-0fc2a424cdab.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/3a88b3cf-0d10-4edc-b6b1-0fc2a424cdab.jpg
# ✅ Moved temporal-landing/images/398e9042-f7a0-43bc-aa76-2624031b24e5.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/398e9042-f7a0-43bc-aa76-2624031b24e5.jpg
# ✅ Moved temporal-landing/images/0608abe5-d145-44e7-bc0d-8b74b558f116.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/syriacus/0608abe5-d145-44e7-bc0d-8b74b558f116.jpg
# ✅ Moved temporal-landing/images/c3fe7f3a-bcb0-43e1-b4c0-5d9173cd220b.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/carinatus/c3fe7f3a-bcb0-43e1-b4c0-5d9173cd220b.jpg
# ✅ Moved temporal-landing/images/73af2f5c-79f6-40fa-ae2f-9da5a6b5e2ea.jpg → persistent_landing/images/Animalia/Squamata/Boidae/bottae/73af2f5c-79f6-40fa-ae2f-9da5a6b5e2ea.jpg
# ✅ Moved temporal-landing/images/495ab344-249b-4d94-bf90-ab738a1915a7.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/495ab344-249b-4d94-bf90-ab738a1915a7.jpg
# ✅ Moved temporal-landing/images/807808c0-f68b-4741-bdc9-33273de6c998.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/807808c0-f68b-4741-bdc9-33273de6c998.jpg
# ✅ Moved temporal-landing/images/3ab208fa-f5a4-48d2-b59d-0277524ccb1e.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/natalensis/3ab208fa-f5a4-48d2-b59d-0277524ccb1e.jpg
# ✅ Moved temporal-landing/images/10bc29f2-b46b-4194-b02c-1e15a98954c4.jpg → persistent_landing/images/Animalia/Squamata/Boidae/bottae/10bc29f2-b46b-4194-b02c-1e15a98954c4.jpg
# ✅ Moved temporal-landing/images/b2ec07f4-8466-4616-b3f3-8626391b863a.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/b2ec07f4-8466-4616-b3f3-8626391b863a.jpg
# ✅ Moved temporal-landing/images/2ce765f1-2113-4eee-8a4e-57dedea08de9.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/multicinctus/2ce765f1-2113-4eee-8a4e-57dedea08de9.jpg
# ✅ Moved temporal-landing/images/e731a0d8-6a0f-4720-b268-3da72dbc022c.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/e731a0d8-6a0f-4720-b268-3da72dbc022c.jpg
# ✅ Moved temporal-landing/images/dc9d123d-9394-4cba-871b-e7b2b3bd8b49.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/dc9d123d-9394-4cba-871b-e7b2b3bd8b49.jpg
# ✅ Moved temporal-landing/images/0303314b-db27-46af-bf35-1ecde7f92e13.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/0303314b-db27-46af-bf35-1ecde7f92e13.jpg
# ✅ Moved temporal-landing/images/10200b26-77e3-4eab-923d-ca0daf430da3.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/10200b26-77e3-4eab-923d-ca0daf430da3.jpg
# ✅ Moved temporal-landing/images/c35bad94-ec3b-4c16-aa0c-c01ce9b70c7e.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/c35bad94-ec3b-4c16-aa0c-c01ce9b70c7e.jpg
# ✅ Moved temporal-landing/images/18e65a74-d3b0-4842-8d02-e08d80596159.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/18e65a74-d3b0-4842-8d02-e08d80596159.jpg
# ✅ Moved temporal-landing/images/6d756441-183f-4be0-8e14-359ec79be921.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/natalensis/6d756441-183f-4be0-8e14-359ec79be921.jpg
# ✅ Moved temporal-landing/images/b650ecb0-268b-4c57-a6af-84e98cd228b8.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/b650ecb0-268b-4c57-a6af-84e98cd228b8.jpg
# ✅ Moved temporal-landing/images/a90c9803-509f-4bb3-a739-957a0349ac35.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/a90c9803-509f-4bb3-a739-957a0349ac35.jpg
# ✅ Moved temporal-landing/images/ac7dc5d2-d43e-4eec-99fb-a4499d7c38ca.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/ac7dc5d2-d43e-4eec-99fb-a4499d7c38ca.jpg
# ✅ Moved temporal-landing/images/43c52401-b15b-4777-bc6a-68661502fff9.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/43c52401-b15b-4777-bc6a-68661502fff9.jpg
# ✅ Moved temporal-landing/images/333d673e-2174-45e5-a301-2ac843208187.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/333d673e-2174-45e5-a301-2ac843208187.jpg
# ✅ Moved temporal-landing/images/8d1a6322-dc39-46bc-9337-72792eebe02e.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/8d1a6322-dc39-46bc-9337-72792eebe02e.jpg
# ✅ Moved temporal-landing/images/77d56cea-ffde-4617-962c-a85bae9ce43e.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/mucruso/77d56cea-ffde-4617-962c-a85bae9ce43e.jpg
# ✅ Moved temporal-landing/images/26f27afb-8191-4b43-b039-0e369b26189f.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/26f27afb-8191-4b43-b039-0e369b26189f.jpg
# ✅ Moved temporal-landing/images/6469c48b-f48a-450d-9a0c-8c48381ad23e.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/contortrix/6469c48b-f48a-450d-9a0c-8c48381ad23e.jpg
# ✅ Moved temporal-landing/images/d0c2b2da-c047-4115-97c2-9f4de3cb3cd4.jpg → persistent_landing/images/Animalia/Squamata/Boidae/unknown/d0c2b2da-c047-4115-97c2-9f4de3cb3cd4.jpg
# ✅ Moved temporal-landing/images/012f73e8-484e-4e51-a20a-d1e1eed1af0d.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/porphyriacus/012f73e8-484e-4e51-a20a-d1e1eed1af0d.jpg
# ✅ Moved temporal-landing/images/eca64457-159a-474c-b437-dbe1e0d345ca.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/capensis/eca64457-159a-474c-b437-dbe1e0d345ca.jpg
# ✅ Moved temporal-landing/images/28e3421e-6e34-4ec0-983e-988b16a727c7.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/28e3421e-6e34-4ec0-983e-988b16a727c7.jpg
# ✅ Moved temporal-landing/images/ead7bb4a-3b92-435d-9d13-72e184d742ae.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/ead7bb4a-3b92-435d-9d13-72e184d742ae.jpg
# ✅ Moved temporal-landing/images/45fa1865-f80d-4d44-a023-73685520999b.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capensis/45fa1865-f80d-4d44-a023-73685520999b.jpg
# ✅ Moved temporal-landing/images/000dc6a9-0adf-4131-92dc-fbdff3949e7a.jpg → persistent_landing/images/Animalia/Squamata/Xenopeltidae/hainanensis/000dc6a9-0adf-4131-92dc-fbdff3949e7a.jpg
# ✅ Moved temporal-landing/images/154fe65b-3805-47cf-ad6f-08ac8d2dca89.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/154fe65b-3805-47cf-ad6f-08ac8d2dca89.jpg
# ✅ Moved temporal-landing/images/9411a014-606a-4293-83cd-c8d7e95d556b.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capensis/9411a014-606a-4293-83cd-c8d7e95d556b.jpg
# ✅ Moved temporal-landing/images/aa2fc298-b6b9-44de-abe3-f3002b4f86c2.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/aa2fc298-b6b9-44de-abe3-f3002b4f86c2.jpg
# ✅ Moved temporal-landing/images/6caf68b2-ebb1-4e59-abb2-c25e757cce08.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/multicinctus/6caf68b2-ebb1-4e59-abb2-c25e757cce08.jpg
# ✅ Moved temporal-landing/images/b389d652-f2f9-4acb-934c-fba15c132107.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/b389d652-f2f9-4acb-934c-fba15c132107.jpg
# ✅ Moved temporal-landing/images/131720e0-d8dd-4295-b200-b67bac9bd52b.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/131720e0-d8dd-4295-b200-b67bac9bd52b.jpg
# ✅ Moved temporal-landing/images/50d3eb00-b004-496e-ac72-933edea92514.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/50d3eb00-b004-496e-ac72-933edea92514.jpg
# ✅ Moved temporal-landing/images/9c97fbb6-86a8-4342-98f8-7b660eb4b21e.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/9c97fbb6-86a8-4342-98f8-7b660eb4b21e.jpg
# ✅ Moved temporal-landing/images/263b61c1-8135-4ce8-b5e9-fdb65aa440c3.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capensis/263b61c1-8135-4ce8-b5e9-fdb65aa440c3.jpg
# ✅ Moved temporal-landing/images/528f2090-59ea-4d50-9d87-aa4ee190ed64.jpg → persistent_landing/images/Animalia/Squamata/Leptotyphlopidae/dulcis/528f2090-59ea-4d50-9d87-aa4ee190ed64.jpg
# ✅ Moved temporal-landing/images/219fed9b-08ce-4d56-b63c-d4d502afc9ae.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/219fed9b-08ce-4d56-b63c-d4d502afc9ae.jpg
# ✅ Moved temporal-landing/images/89479826-54ea-49dc-aa05-9a4808673e14.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/multicinctus/89479826-54ea-49dc-aa05-9a4808673e14.jpg
# ✅ Moved temporal-landing/images/bf4fcfe4-6f31-4ce1-8752-a3f880d646c3.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/bf4fcfe4-6f31-4ce1-8752-a3f880d646c3.jpg
# ✅ Moved temporal-landing/images/e21b3275-b09e-4b46-aa83-85490f6d819e.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/e21b3275-b09e-4b46-aa83-85490f6d819e.jpg
# ✅ Moved temporal-landing/images/a3ea15a0-b416-40f7-a9b0-195d88921844.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/a3ea15a0-b416-40f7-a9b0-195d88921844.jpg
# ✅ Moved temporal-landing/images/08a20784-4507-4997-8e7c-e79346e409f2.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/vermicularis/08a20784-4507-4997-8e7c-e79346e409f2.jpg
# ✅ Moved temporal-landing/images/d00418ea-e17d-4bd9-86b0-c5a7a996ecb4.jpg → persistent_landing/images/Animalia/Squamata/Boidae/bottae/d00418ea-e17d-4bd9-86b0-c5a7a996ecb4.jpg
# ✅ Moved temporal-landing/images/0b1837de-7cee-47af-b09f-c6df1c3cc9a0.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/superbus/0b1837de-7cee-47af-b09f-c6df1c3cc9a0.jpg
# ✅ Moved temporal-landing/images/719c1345-e687-4fa8-a9c4-a54d3fa98ab0.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/719c1345-e687-4fa8-a9c4-a54d3fa98ab0.jpg
# ✅ Moved temporal-landing/images/63cb3126-ae58-4661-9ea2-5e760594c925.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/63cb3126-ae58-4661-9ea2-5e760594c925.jpg
# ✅ Moved temporal-landing/images/3bba08df-beb4-44d4-a355-d13ce13e7730.jpg → persistent_landing/images/Animalia/Squamata/Boidae/bottae/3bba08df-beb4-44d4-a355-d13ce13e7730.jpg
# ✅ Moved temporal-landing/images/645c9eee-8b48-4685-9e78-2b6b9e99ce6f.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/superbus/645c9eee-8b48-4685-9e78-2b6b9e99ce6f.jpg
# ✅ Moved temporal-landing/images/580ac841-febe-48c3-a12c-e164a527fe24.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/580ac841-febe-48c3-a12c-e164a527fe24.jpg
# ✅ Moved temporal-landing/images/0ba5c87f-e938-455e-bd19-8381f87a7407.jpg → persistent_landing/images/Animalia/Squamata/Leptotyphlopidae/dulcis/0ba5c87f-e938-455e-bd19-8381f87a7407.jpg
# ✅ Moved temporal-landing/images/54d918cf-221a-49df-bf06-8305e6691846.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/54d918cf-221a-49df-bf06-8305e6691846.jpg
# ✅ Moved temporal-landing/images/6ea6163b-0393-45c2-9d6d-ffa0f01da15b.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/braminus/6ea6163b-0393-45c2-9d6d-ffa0f01da15b.jpg
# ✅ Moved temporal-landing/images/840c1dfc-4b03-4ec2-89e4-36ec323d450c.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/840c1dfc-4b03-4ec2-89e4-36ec323d450c.jpg
# ✅ Moved temporal-landing/images/c7f46728-ead1-4695-ac1d-59828b1265ff.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/spilota/c7f46728-ead1-4695-ac1d-59828b1265ff.jpg
# ✅ Moved temporal-landing/images/ccd4d3cc-b515-472f-8cc0-18ca84d511a2.jpg → persistent_landing/images/Animalia/Squamata/Boidae/bottae/ccd4d3cc-b515-472f-8cc0-18ca84d511a2.jpg
# ✅ Moved temporal-landing/images/d5dda7d5-f57f-4f39-b06a-aaf79292b0b6.jpg → persistent_landing/images/Animalia/Squamata/Cylindrophiidae/ruffus/d5dda7d5-f57f-4f39-b06a-aaf79292b0b6.jpg
# ✅ Moved temporal-landing/images/729b18ee-ee2c-44bd-b370-ca071d95dc61.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/729b18ee-ee2c-44bd-b370-ca071d95dc61.jpg
# ✅ Moved temporal-landing/images/2f82a78f-934e-4b75-9159-832851363f82.jpg → persistent_landing/images/Animalia/Squamata/Boidae/imperator/2f82a78f-934e-4b75-9159-832851363f82.jpg
# ✅ Moved temporal-landing/images/79d1c3ab-fbff-4e06-9fa0-af6f51470841.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/miliarius/79d1c3ab-fbff-4e06-9fa0-af6f51470841.jpg
# ✅ Moved temporal-landing/images/172874c2-23fc-48f9-aefb-16496fd7b17a.jpg → persistent_landing/images/Animalia/Squamata/Boidae/maurus/172874c2-23fc-48f9-aefb-16496fd7b17a.jpg
# ✅ Moved temporal-landing/images/4812fcf8-bacf-409a-9ec6-3f8ef6a87687.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/cerastes/4812fcf8-bacf-409a-9ec6-3f8ef6a87687.jpg
# ...
# ✅ Moved temporal-landing/images/dbb564e8-b300-4af7-acff-d9b727f5f307.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/lalandei/dbb564e8-b300-4af7-acff-d9b727f5f307.jpg
# ✅ Moved temporal-landing/images/7b05b30c-795b-410f-8916-fa8856491cea.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/aurora/7b05b30c-795b-410f-8916-fa8856491cea.jpg
# ✅ Moved temporal-landing/images/64184a6d-5c58-422c-bc2e-75744aaa9d60.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/dendrophila/64184a6d-5c58-422c-bc2e-75744aaa9d60.jpg
# ✅ Moved temporal-landing/images/caf96062-3c6b-4eea-a531-279ce963122e.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/mucruso/caf96062-3c6b-4eea-a531-279ce963122e.jpg
# ✅ Moved temporal-landing/images/db1e60ed-406e-485f-ba4c-ce00c38feed9.jpg → persistent_landing/images/Animalia/Squamata/Aniliidae/scytale/db1e60ed-406e-485f-ba4c-ce00c38feed9.jpg
# ✅ Moved temporal-landing/images/4b35abd3-efc8-4974-a4ed-1e6cf4a23c6c.jpg → persistent_landing/images/Animalia/Squamata/Boidae/maurus/4b35abd3-efc8-4974-a4ed-1e6cf4a23c6c.jpg
# ✅ Moved temporal-landing/images/066d50eb-e5b1-4da8-be19-8e066db71a81.jpg → persistent_landing/images/Animalia/Squamata/Xenopeltidae/unicolor/066d50eb-e5b1-4da8-be19-8e066db71a81.jpg
# ✅ Moved temporal-landing/images/48f7a71f-5400-49d3-b913-fd6058b2fdbf.jpg → persistent_landing/images/Animalia/Squamata/Cylindrophiidae/jodiae/48f7a71f-5400-49d3-b913-fd6058b2fdbf.jpg
# ✅ Moved temporal-landing/images/48fad3b3-e956-4a68-a12c-aed91d16f4ac.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/totonacus/48fad3b3-e956-4a68-a12c-aed91d16f4ac.jpg
# ✅ Moved temporal-landing/images/52b4d2ee-335b-4041-ba11-cf68e919c1ab.jpg → persistent_landing/images/Animalia/Squamata/Xenopeltidae/unicolor/52b4d2ee-335b-4041-ba11-cf68e919c1ab.jpg
# ✅ Moved temporal-landing/images/8dbea35a-a678-429c-bc14-b5e0efc38c46.jpg → persistent_landing/images/Animalia/Squamata/Xenopeltidae/unicolor/8dbea35a-a678-429c-bc14-b5e0efc38c46.jpg
# ✅ Moved temporal-landing/images/911e913e-949f-4e57-94a2-ce21c07e7267.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/parvifrons/911e913e-949f-4e57-94a2-ce21c07e7267.jpg
# ✅ Moved temporal-landing/images/bcda2290-6bd8-45b5-9588-b16cfb9f9f62.jpg → persistent_landing/images/Animalia/Squamata/Boidae/carinata/bcda2290-6bd8-45b5-9588-b16cfb9f9f62.jpg
# ✅ Moved temporal-landing/images/299b1153-ed87-4133-8aec-6fcc0c828b9a.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/imbricata/299b1153-ed87-4133-8aec-6fcc0c828b9a.jpg
# ✅ Moved temporal-landing/images/858d7754-9899-47af-b739-b73038cee6e2.jpg → persistent_landing/images/Animalia/Squamata/Cylindrophiidae/ruffus/858d7754-9899-47af-b739-b73038cee6e2.jpg
# ✅ Moved temporal-landing/images/5a5ae93c-3a6a-42aa-a85c-c6ab70fcc516.jpg → persistent_landing/images/Animalia/Squamata/Uropeltidae/madurensis/5a5ae93c-3a6a-42aa-a85c-c6ab70fcc516.jpg
# ✅ Moved temporal-landing/images/36659a3c-aaf6-48ec-9c3a-aeaab5c5ed12.jpg → persistent_landing/images/Animalia/Squamata/Boidae/maurus/36659a3c-aaf6-48ec-9c3a-aeaab5c5ed12.jpg
# ✅ Moved temporal-landing/images/92c0c8dc-9383-480c-93fb-dd1eb724bdd7.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capense/92c0c8dc-9383-480c-93fb-dd1eb724bdd7.jpg
# ✅ Moved temporal-landing/images/9c783307-d052-454b-bd59-610b835c99d9.jpg → persistent_landing/images/Animalia/Squamata/Boidae/maurus/9c783307-d052-454b-bd59-610b835c99d9.jpg
# ✅ Moved temporal-landing/images/c6204c8b-b9aa-4e65-a631-f9472df2ab42.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lacteus/c6204c8b-b9aa-4e65-a631-f9472df2ab42.jpg
# ✅ Moved temporal-landing/images/662b1933-d2fb-4d6b-9c9b-22cb70c46fee.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/lalandei/662b1933-d2fb-4d6b-9c9b-22cb70c46fee.jpg
# ✅ Moved temporal-landing/images/2c207382-8fec-485e-b5f0-47d1280d928d.jpg → persistent_landing/images/Animalia/Squamata/Loxocemidae/bicolor/2c207382-8fec-485e-b5f0-47d1280d928d.jpg
# ✅ Moved temporal-landing/images/591fb9db-1a16-4f60-ad7b-61dec50f98d9.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capense/591fb9db-1a16-4f60-ad7b-61dec50f98d9.jpg
# ✅ Moved temporal-landing/images/43f8db43-7928-47ed-bad5-dd5dff6a7f16.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/carinatus/43f8db43-7928-47ed-bad5-dd5dff6a7f16.jpg
# ✅ Moved temporal-landing/images/91f8afa5-d8b6-4a84-9760-4184717e62f7.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/imbricata/91f8afa5-d8b6-4a84-9760-4184717e62f7.jpg
# ✅ Moved temporal-landing/images/44e23249-42e7-43b6-b179-4fd2e02aa9d5.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/microlepidotus/44e23249-42e7-43b6-b179-4fd2e02aa9d5.jpg
# ✅ Moved temporal-landing/images/d29470c4-1bbf-403a-a7d9-446a90b9ed09.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capense/d29470c4-1bbf-403a-a7d9-446a90b9ed09.jpg
# ✅ Moved temporal-landing/images/d26889b3-caef-4ad1-8d1e-ba995d70b904.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/carinatus/d26889b3-caef-4ad1-8d1e-ba995d70b904.jpg
# ✅ Moved temporal-landing/images/9a8c910f-81fe-4a4e-bad8-8a0dfc175b2e.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/parvifrons/9a8c910f-81fe-4a4e-bad8-8a0dfc175b2e.jpg
# ✅ Moved temporal-landing/images/6c9f4474-fdc1-4a3f-a05c-de32c77b6888.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/syriacus/6c9f4474-fdc1-4a3f-a05c-de32c77b6888.jpg
# ✅ Moved temporal-landing/images/b3e5e1af-4975-4b64-b6a6-3f1d2dbfb00b.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capense/b3e5e1af-4975-4b64-b6a6-3f1d2dbfb00b.jpg
# ✅ Moved temporal-landing/images/4ee9a3eb-6d08-47d0-a9db-8aaabdf23016.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/totonacus/4ee9a3eb-6d08-47d0-a9db-8aaabdf23016.jpg
# ✅ Moved temporal-landing/images/361f78e1-8882-4202-9d48-7dd34635fa77.jpg → persistent_landing/images/Animalia/Squamata/Anomalepididae/ternetzii/361f78e1-8882-4202-9d48-7dd34635fa77.jpg
# ✅ Moved temporal-landing/images/ea7dd5bc-fd25-41e4-9d26-fb8e03001de0.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/totonacus/ea7dd5bc-fd25-41e4-9d26-fb8e03001de0.jpg
# ✅ Moved temporal-landing/images/c28602ce-ccab-496d-a261-9b1859fbf637.jpg → persistent_landing/images/Animalia/Squamata/Leptotyphlopidae/scutifrons/c28602ce-ccab-496d-a261-9b1859fbf637.jpg
# ✅ Moved temporal-landing/images/33d775ed-1f1e-4c49-be58-0caef3c34cfb.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/dendrophila/33d775ed-1f1e-4c49-be58-0caef3c34cfb.jpg
# ✅ Moved temporal-landing/images/25892da1-8044-4038-88d0-f51734e8052e.jpg → persistent_landing/images/Animalia/Squamata/Xenopeltidae/unicolor/25892da1-8044-4038-88d0-f51734e8052e.jpg
# ✅ Moved temporal-landing/images/1387e968-8cfa-427e-b446-fba00c957fad.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/dendrophila/1387e968-8cfa-427e-b446-fba00c957fad.jpg
# ✅ Moved temporal-landing/images/6976b0b7-003e-4a35-a963-e56aecfc6a0d.jpg → persistent_landing/images/Animalia/Squamata/Loxocemidae/bicolor/6976b0b7-003e-4a35-a963-e56aecfc6a0d.jpg
# ✅ Moved temporal-landing/images/9e160e23-509a-46ac-9a57-b88f461b8ca2.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/imbricata/9e160e23-509a-46ac-9a57-b88f461b8ca2.jpg
# ✅ Moved temporal-landing/images/df79a5be-51b5-47c2-9e1f-8913a09bbb35.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/imbricata/df79a5be-51b5-47c2-9e1f-8913a09bbb35.jpg
# ✅ Moved temporal-landing/images/0f72b3a1-26c1-45c2-8264-0a9f5c1ca7a7.jpg → persistent_landing/images/Animalia/Squamata/Uropeltidae/madurensis/0f72b3a1-26c1-45c2-8264-0a9f5c1ca7a7.jpg
# ✅ Moved temporal-landing/images/dcb255b8-60f5-4a43-8b03-a78025fbd94c.jpg → persistent_landing/images/Animalia/Squamata/Cylindrophiidae/ruffus/dcb255b8-60f5-4a43-8b03-a78025fbd94c.jpg
# ✅ Moved temporal-landing/images/4a71f43f-38c6-40fe-95d6-956070a563d3.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lacteus/4a71f43f-38c6-40fe-95d6-956070a563d3.jpg
# ✅ Moved temporal-landing/images/b1021184-71c6-420c-b4b5-722270eea830.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/mucruso/b1021184-71c6-420c-b4b5-722270eea830.jpg
# ✅ Moved temporal-landing/images/c93f73b2-31f5-42da-b238-bdedd86f3447.jpg → persistent_landing/images/Animalia/Squamata/Xenopeltidae/unicolor/c93f73b2-31f5-42da-b238-bdedd86f3447.jpg
# ✅ Moved temporal-landing/images/3f10b458-b340-4740-a101-5e0bd1919dcf.jpg → persistent_landing/images/Animalia/Squamata/Cylindrophiidae/jodiae/3f10b458-b340-4740-a101-5e0bd1919dcf.jpg
# ✅ Moved temporal-landing/images/a0bf6cf6-7760-41ab-9e7c-47fcf23b9edb.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lacteus/a0bf6cf6-7760-41ab-9e7c-47fcf23b9edb.jpg
# ✅ Moved temporal-landing/images/1ca7316b-4f2f-4fad-8182-f4e274185226.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/dendrophila/1ca7316b-4f2f-4fad-8182-f4e274185226.jpg
# ✅ Moved temporal-landing/images/3860b467-1dbf-4eaf-9181-e61615c15eca.jpg → persistent_landing/images/Animalia/Squamata/Anomalepididae/ternetzii/3860b467-1dbf-4eaf-9181-e61615c15eca.jpg
# ✅ Moved temporal-landing/images/8f802fd8-e81b-4411-912a-2cb93974ddde.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/imbricata/8f802fd8-e81b-4411-912a-2cb93974ddde.jpg
# ✅ Moved temporal-landing/images/08758706-7fe9-4c92-b239-421e0171492a.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lunulatus/08758706-7fe9-4c92-b239-421e0171492a.jpg
# ✅ Moved temporal-landing/images/3c8f775f-da6b-4c8b-a935-7726b9ae9903.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/mucruso/3c8f775f-da6b-4c8b-a935-7726b9ae9903.jpg
# ✅ Moved temporal-landing/images/d4b50603-f521-40e6-a34a-9089d70633d3.jpg → persistent_landing/images/Animalia/Squamata/Cylindrophiidae/melanotus/d4b50603-f521-40e6-a34a-9089d70633d3.jpg
# ✅ Moved temporal-landing/images/0e4e27ae-69fe-4e4a-996b-bd7b6aa3b408.jpg → persistent_landing/images/Animalia/Squamata/Anomalepididae/anops/0e4e27ae-69fe-4e4a-996b-bd7b6aa3b408.jpg
# ✅ Moved temporal-landing/images/776fbea2-ddae-4c03-8155-1826453c104f.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/dendrophila/776fbea2-ddae-4c03-8155-1826453c104f.jpg
# ✅ Moved temporal-landing/images/ea8e8070-b86d-45bd-a4e3-8a4fef572f78.jpg → persistent_landing/images/Animalia/Squamata/Loxocemidae/bicolor/ea8e8070-b86d-45bd-a4e3-8a4fef572f78.jpg
# ✅ Moved temporal-landing/images/70474c26-a4dc-4920-9c60-c928f2f1e560.jpg → persistent_landing/images/Animalia/Squamata/Anomalepididae/albirostris/70474c26-a4dc-4920-9c60-c928f2f1e560.jpg
# ✅ Moved temporal-landing/images/c972e7b5-3570-41a8-a42d-45b4be28c509.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/microlepidotus/c972e7b5-3570-41a8-a42d-45b4be28c509.jpg
# ✅ Moved temporal-landing/images/1f9e35b4-5733-4e24-ae42-bda121818bc1.jpg → persistent_landing/images/Animalia/Squamata/Pythonidae/breitensteini/1f9e35b4-5733-4e24-ae42-bda121818bc1.jpg
# ✅ Moved temporal-landing/images/876de275-ec10-4fe8-a777-b82ed1fb7d92.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lacteus/876de275-ec10-4fe8-a777-b82ed1fb7d92.jpg
# ✅ Moved temporal-landing/images/61716594-47cc-4ec1-a6ff-902512360b1a.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/capense/61716594-47cc-4ec1-a6ff-902512360b1a.jpg
# ✅ Moved temporal-landing/images/092446e0-c3cb-45d7-822c-27ca5df3ec4b.jpg → persistent_landing/images/Animalia/Squamata/Xenopeltidae/unicolor/092446e0-c3cb-45d7-822c-27ca5df3ec4b.jpg
# ✅ Moved temporal-landing/images/71671930-7177-4519-af7b-24bee08056b6.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/dendrophila/71671930-7177-4519-af7b-24bee08056b6.jpg
# ✅ Moved temporal-landing/images/731e0c5c-729a-47ae-9355-0e5b8db26842.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/mucruso/731e0c5c-729a-47ae-9355-0e5b8db26842.jpg
# ✅ Moved temporal-landing/images/8d492da4-e087-4a20-b81c-154de8e776c5.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/dendrophila/8d492da4-e087-4a20-b81c-154de8e776c5.jpg
# ✅ Moved temporal-landing/images/c315e665-698a-4ba7-a0fb-a62cd21db464.jpg → persistent_landing/images/Animalia/Squamata/Colubridae/dendrophila/c315e665-698a-4ba7-a0fb-a62cd21db464.jpg
# ✅ Moved temporal-landing/images/43632685-3ef8-4a05-a45e-7a1d5f95a911.jpg → persistent_landing/images/Animalia/Squamata/Cylindrophiidae/boulengeri/43632685-3ef8-4a05-a45e-7a1d5f95a911.jpg
# ✅ Moved temporal-landing/images/72fa54ef-e00d-430e-b789-50cdcbc71e06.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/mucruso/72fa54ef-e00d-430e-b789-50cdcbc71e06.jpg
# ✅ Moved temporal-landing/images/8b181126-7f73-491d-95cf-cb36953e9aed.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/mucruso/8b181126-7f73-491d-95cf-cb36953e9aed.jpg
# ✅ Moved temporal-landing/images/5ff6a7c4-ed02-405a-a522-c179c108235e.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lacteus/5ff6a7c4-ed02-405a-a522-c179c108235e.jpg
# ✅ Moved temporal-landing/images/53281836-a794-4b77-a8e1-e7afaabecf50.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/aurora/53281836-a794-4b77-a8e1-e7afaabecf50.jpg
# ✅ Moved temporal-landing/images/20485546-59fb-408f-9eb7-1f64f7598df0.jpg → persistent_landing/images/Animalia/Squamata/Lamprophiidae/aurora/20485546-59fb-408f-9eb7-1f64f7598df0.jpg
# ✅ Moved temporal-landing/images/337cc09c-8e77-444a-831e-5bc666058fca.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/microlepidotus/337cc09c-8e77-444a-831e-5bc666058fca.jpg
# ✅ Moved temporal-landing/images/90a4808e-d651-415a-af96-2c961a84fd28.jpg → persistent_landing/images/Animalia/Squamata/Leptotyphlopidae/scutifrons/90a4808e-d651-415a-af96-2c961a84fd28.jpg
# ✅ Moved temporal-landing/images/2b9de360-6520-4f56-8e76-6d408d86f3b2.jpg → persistent_landing/images/Animalia/Squamata/Aniliidae/scytale/2b9de360-6520-4f56-8e76-6d408d86f3b2.jpg
# ✅ Moved temporal-landing/images/4388f3bd-d6d6-4cd6-95f0-cd12c96ea18d.jpg → persistent_landing/images/Animalia/Squamata/Leptotyphlopidae/scutifrons/4388f3bd-d6d6-4cd6-95f0-cd12c96ea18d.jpg
# ✅ Moved temporal-landing/images/b84c93a9-ba71-4516-b442-e263ba39953c.jpg → persistent_landing/images/Animalia/Squamata/Typhlopidae/mucruso/b84c93a9-ba71-4516-b442-e263ba39953c.jpg
# ✅ Moved temporal-landing/images/19709a25-163c-499b-bd48-faccea6e1d8b.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/carinatus/19709a25-163c-499b-bd48-faccea6e1d8b.jpg
# ✅ Moved temporal-landing/images/116f4990-6990-431d-aac1-032e79882bed.jpg → persistent_landing/images/Animalia/Squamata/Aniliidae/scytale/116f4990-6990-431d-aac1-032e79882bed.jpg
# ✅ Moved temporal-landing/images/65c4ea95-2778-4017-901f-2b67b8bd6a62.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lacteus/65c4ea95-2778-4017-901f-2b67b8bd6a62.jpg
# ✅ Moved temporal-landing/images/29323114-89e1-4a0f-8f32-7e63c0ca8dbf.jpg → persistent_landing/images/Animalia/Squamata/Anomalepididae/ternetzii/29323114-89e1-4a0f-8f32-7e63c0ca8dbf.jpg
# ✅ Moved temporal-landing/images/16490221-8763-4d63-b60d-10b74d0c7e8e.jpg → persistent_landing/images/Animalia/Squamata/Atractaspididae/lacteus/16490221-8763-4d63-b60d-10b74d0c7e8e.jpg
# ✅ Moved temporal-landing/images/d4f6b234-07f7-4132-a069-d354dfd8d5de.jpg → persistent_landing/images/Animalia/Squamata/Elapidae/carinatus/d4f6b234-07f7-4132-a069-d354dfd8d5de.jpg
# ✅ Moved temporal-landing/images/ed7aa646-b877-4a87-a37e-c90775c43b9e.jpg → persistent_landing/images/Animalia/Squamata/Viperidae/totonacus/ed7aa646-b877-4a87-a37e-c90775c43b9e.jpg
# ✅ Moved temporal-landing/images/3b099339-c306-4bc4-9fb4-fb2dc5bc5e50.jpg → persistent_landing/images/Animalia/Squamata/Loxocemidae/bicolor/3b099339-c306-4bc4-9fb4-fb2dc5bc5e50.jpg
# 🧠 Updating kingdom-class based metadata files...
# 📤 Updated/uploaded metadata for 'Animalia-Squamata' → persistent_landing/metadata/Animalia_Squamata_metadata_2025_10_13_01:34.csv
# 🧹 Cleaned up local metadata files.
# ✅ Persistent Landing Zone completed successfully.
